# %% [markdown]
# # Genre Analysis for Project
# -----------------------------

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.dates import YearLocator

# %%
# read in cleaned dataframe csv
movies = "Final_Data.csv"

Movies_df = pd.read_csv(movies)

# view cleaned dataframe and its index
print(Movies_df.columns)

Movies_df.head()
# Out:
# Index(['Title', 'Budget', 'Domestic_Gross', 'Year', 'Crit_Rating',
#        'Aud_Rating', 'Runtime_Min', 'Genre', 'MPAA_Rating'],
#       dtype='object')
#             Title    Budget  Domestic_Gross  Year  Crit_Rating  Aud_Rating  \
# 0   VARSITY BLUES  16000000        52894169  1999           41        76.0
# 1  AT FIRST SIGHT  40000000        22365133  1999           32        46.0
# 2           VIRUS  75000000        14010690  1999           10        21.0
# 3       IN DREAMS  30000000        12017369  1999           24        40.0
# 4   SHES ALL THAT  10000000        63465522  1999           40        55.0
#
#    Runtime_Min                                              Genre MPAA_Rating
# 0        104.0                                              Drama           R
# 1        128.0                                     Drama, Romance       PG-13
# 2        100.0  Action & Adventure, Horror, Science Fiction & ...           R
# 3        120.0                         Horror, Mystery & Suspense           R
# 4         95.0                             Comedy, Drama, Romance       PG-13

# %%
# Need ROI for movies df

#Create a function that returns ROI
def roi(Domestic_Gross, Budget):
    
    return ((Domestic_Gross - Budget)/Budget) *100
  
# Create a variable that is the output of the function for ROI
Movies_df['ROI %'] = roi(Movies_df['Domestic_Gross'], Movies_df['Budget'])

# View the new dataframe
Movies_df.head (5)
# Out:
#             Title    Budget  Domestic_Gross  Year  Crit_Rating  Aud_Rating  \
# 0   VARSITY BLUES  16000000        52894169  1999           41        76.0
# 1  AT FIRST SIGHT  40000000        22365133  1999           32        46.0
# 2           VIRUS  75000000        14010690  1999           10        21.0
# 3       IN DREAMS  30000000        12017369  1999           24        40.0
# 4   SHES ALL THAT  10000000        63465522  1999           40        55.0
#
#    Runtime_Min                                              Genre MPAA_Rating  \
# 0        104.0                                              Drama           R
# 1        128.0                                     Drama, Romance       PG-13
# 2        100.0  Action & Adventure, Horror, Science Fiction & ...           R
# 3        120.0                         Horror, Mystery & Suspense           R
# 4         95.0                             Comedy, Drama, Romance       PG-13
#
#         ROI %
# 0  230.588556
# 1  -44.087167
# 2  -81.319080
# 3  -59.942103
# 4  534.655220

# %% [markdown]
# ## 2018-2014 build for Avg. ROI for last 5 years

# %%
Movies_df.head ()
# Out:
#             Title    Budget  Domestic_Gross  Year  Crit_Rating  Aud_Rating  \
# 0   VARSITY BLUES  16000000        52894169  1999           41        76.0
# 1  AT FIRST SIGHT  40000000        22365133  1999           32        46.0
# 2           VIRUS  75000000        14010690  1999           10        21.0
# 3       IN DREAMS  30000000        12017369  1999           24        40.0
# 4   SHES ALL THAT  10000000        63465522  1999           40        55.0
#
#    Runtime_Min                                              Genre MPAA_Rating  \
# 0        104.0                                              Drama           R
# 1        128.0                                     Drama, Romance       PG-13
# 2        100.0  Action & Adventure, Horror, Science Fiction & ...           R
# 3        120.0                         Horror, Mystery & Suspense           R
# 4         95.0                             Comedy, Drama, Romance       PG-13
#
#         ROI %
# 0  230.588556
# 1  -44.087167
# 2  -81.319080
# 3  -59.942103
# 4  534.655220

# %%
#creating dataframe for years 2018-2014 only
Movieslast5years_df = Movies_df[(Movies_df['Year']  > 2013)] 

Movieslast5years_df.head(5)
# Out:
#                                      Title    Budget  Domestic_Gross  Year  \
# 1816  PARANORMAL ACTIVITY: THE MARKED ONES   5000000        32462372  2014
# 1817                THE LEGEND OF HERCULES  70000000        18848538  2014
# 1818                            RIDE ALONG  25000000       134202565  2014
# 1819                           THE NUT JOB  30000000        64251538  2014
# 1820             JACK RYAN: SHADOW RECRUIT  60000000        50577412  2014
#
#       Crit_Rating  Aud_Rating  Runtime_Min  \
# 1816           39        34.0         84.0
# 1817            3        33.0         99.0
# 1818           18        58.0         99.0
# 1819           12        43.0         86.0
# 1820           55        53.0        105.0
#
#                                               Genre MPAA_Rating       ROI %
# 1816                                         Horror           R  549.247440
# 1817  Action & Adventure, Science Fiction & Fantasy       PG-13  -73.073517
# 1818                     Action & Adventure, Comedy       PG-13  436.810260
# 1819                              Animation, Comedy          PG  114.171793
# 1820  Action & Adventure, Drama, Mystery & Suspense       PG-13  -15.704313

# %%
#Create pivot table to group by genre and get AVG ROI%
Moviespivotlast5yearsbygenre = pd.pivot_table(Movieslast5years_df, index=['Genre'], aggfunc='mean')

#View pivot table
Moviespivotlast5yearsbygenre.head ()
# Out:
#                                                     Aud_Rating       Budget  \
# Genre
# Action & Adventure                                   50.650000   80650000.0
# Action & Adventure, Animation, Comedy                57.000000   84000000.0
# Action & Adventure, Animation, Comedy, Kids & F...   67.000000   92500000.0
# Action & Adventure, Animation, Comedy, Kids & F...   63.500000   95000000.0
# Action & Adventure, Animation, Kids & Family         81.666667  120000000.0
#
#                                                     Crit_Rating  \
# Genre
# Action & Adventure                                    34.600000
# Action & Adventure, Animation, Comedy                 53.000000
# Action & Adventure, Animation, Comedy, Kids & F...    70.300000
# Action & Adventure, Animation, Comedy, Kids & F...    63.500000
# Action & Adventure, Animation, Kids & Family          93.666667
#
#                                                     Domestic_Gross  \
# Genre
# Action & Adventure                                    8.049816e+07
# Action & Adventure, Animation, Comedy                 1.791654e+08
# Action & Adventure, Animation, Comedy, Kids & F...    1.219701e+08
# Action & Adventure, Animation, Comedy, Kids & F...    1.141174e+08
# Action & Adventure, Animation, Kids & Family          2.957097e+08
#
#                                                          ROI %  Runtime_Min  \
# Genre
# Action & Adventure                                   19.554161   110.900000
# Action & Adventure, Animation, Comedy                61.151913    97.000000
# Action & Adventure, Animation, Comedy, Kids & F...   60.898870    95.888889
# Action & Adventure, Animation, Comedy, Kids & F...   10.594232    95.000000
# Action & Adventure, Animation, Kids & Family        156.010420   104.333333
#
#                                                            Year
# Genre
# Action & Adventure                                  2015.050000
# Action & Adventure, Animation, Comedy               2016.000000
# Action & Adventure, Animation, Comedy, Kids & F...  2016.500000
# Action & Adventure, Animation, Comedy, Kids & F...  2014.500000
# Action & Adventure, Animation, Kids & Family        2017.333333

# %%
#Create Dataframe from pivot table
MoviesL5yrs_df = Moviespivotlast5yearsbygenre.reset_index()

#view new dataframe 
MoviesL5yrs_df.head ()
# Out:
#                                                Genre  Aud_Rating       Budget  \
# 0                                 Action & Adventure   50.650000   80650000.0
# 1              Action & Adventure, Animation, Comedy   57.000000   84000000.0
# 2  Action & Adventure, Animation, Comedy, Kids & ...   67.000000   92500000.0
# 3  Action & Adventure, Animation, Comedy, Kids & ...   63.500000   95000000.0
# 4       Action & Adventure, Animation, Kids & Family   81.666667  120000000.0
#
#    Crit_Rating  Domestic_Gross       ROI %  Runtime_Min         Year
# 0    34.600000    8.049816e+07   19.554161   110.900000  2015.050000
# 1    53.000000    1.791654e+08   61.151913    97.000000  2016.000000
# 2    70.300000    1.219701e+08   60.898870    95.888889  2016.500000
# 3    63.500000    1.141174e+08   10.594232    95.000000  2014.500000
# 4    93.666667    2.957097e+08  156.010420   104.333333  2017.333333

# %%
#Sorted Dataframe for top 5 Genres
MoviesL5yrs_df= MoviesL5yrs_df.nlargest(5, 'ROI %')

#view df
MoviesL5yrs_df.head ()
# Out:
#                                              Genre  Aud_Rating        Budget  \
# 73                      Horror, Mystery & Suspense   49.625000  5.762500e+06
# 59               Drama, Horror, Mystery & Suspense   74.000000  2.175000e+07
# 23  Action & Adventure, Horror, Mystery & Suspense   37.333333  6.666667e+06
# 51               Comedy, Musical & Performing Arts   64.000000  2.900000e+07
# 71                                          Horror   41.481481  1.229259e+07
#
#     Crit_Rating  Domestic_Gross        ROI %  Runtime_Min         Year
# 73    57.500000    5.897737e+07  3994.556035    93.142857  2016.000000
# 59    81.750000    1.678619e+08  1115.963209   114.000000  2017.250000
# 23    37.666667    4.668842e+07   570.293667    90.000000  2015.666667
# 51    66.000000    1.842962e+08   535.504241   114.000000  2015.000000
# 71    44.037037    4.677825e+07   431.240898    97.125000  2016.037037

# %%
#Create bar graph to visualize df
MoviesL5yrs_df.plot(kind='barh', x = 'Genre', y= 'ROI %', legend =None)

plt.title('Top 5 Movie Genres by Avg ROI 2014-2018')
plt.ylabel('Genres')
plt.xlabel ('% (Avg ROI of all movies produced in that Genre)')


plt.savefig('Genre_Aoutput/'+ 'L5yrstop5genresROI.png', bbox_inches='tight')

# %% [markdown]
# ##  Build for Line graph using  Top 5 genres with Highest ROI AVG from 2018-2014

# %%
#brought in df and viewed
Movieslast5years_df.head ()
# Out:
#                                      Title    Budget  Domestic_Gross  Year  \
# 1816  PARANORMAL ACTIVITY: THE MARKED ONES   5000000        32462372  2014
# 1817                THE LEGEND OF HERCULES  70000000        18848538  2014
# 1818                            RIDE ALONG  25000000       134202565  2014
# 1819                           THE NUT JOB  30000000        64251538  2014
# 1820             JACK RYAN: SHADOW RECRUIT  60000000        50577412  2014
#
#       Crit_Rating  Aud_Rating  Runtime_Min  \
# 1816           39        34.0         84.0
# 1817            3        33.0         99.0
# 1818           18        58.0         99.0
# 1819           12        43.0         86.0
# 1820           55        53.0        105.0
#
#                                               Genre MPAA_Rating       ROI %
# 1816                                         Horror           R  549.247440
# 1817  Action & Adventure, Science Fiction & Fantasy       PG-13  -73.073517
# 1818                     Action & Adventure, Comedy       PG-13  436.810260
# 1819                              Animation, Comedy          PG  114.171793
# 1820  Action & Adventure, Drama, Mystery & Suspense       PG-13  -15.704313

# %%
#create new pivot with year grouping and roi sorted by Genres
MoviesGerebyYrpivotROI= Movieslast5years_df.pivot_table(index=['Year'], columns=['Genre'], aggfunc='mean', values=['ROI %'])

#view new pivot
MoviesGerebyYrpivotROI.head ()
# Out:
#                    ROI %                                        \
# Genre Action & Adventure Action & Adventure, Animation, Comedy
# Year
# 2014           73.148830                                   NaN
# 2015           -3.469511                                   NaN
# 2016           20.111939                             61.151913
# 2017                 NaN                                   NaN
# 2018            3.167880                                   NaN
#
#                                                             \
# Genre Action & Adventure, Animation, Comedy, Kids & Family
# Year
# 2014                                          153.271091
# 2015                                          -33.824129
# 2016                                                 NaN
# 2017                                           57.114832
# 2018                                           35.937105
#
#                                                                                        \
# Genre Action & Adventure, Animation, Comedy, Kids & Family, Science Fiction & Fantasy
# Year
# 2014                                          -15.271158
# 2015                                           36.459623
# 2016                                                 NaN
# 2017                                                 NaN
# 2018                                                 NaN
#
#                                                     \
# Genre Action & Adventure, Animation, Kids & Family
# Year
# 2014                                           NaN
# 2015                                           NaN
# 2016                                     65.838029
# 2017                                           NaN
# 2018                                    201.096616
#
#                                                                                \
# Genre Action & Adventure, Animation, Kids & Family, Science Fiction & Fantasy
# Year
# 2014                                           22.070982
# 2015                                                 NaN
# 2016                                                 NaN
# 2017                                                 NaN
# 2018                                          111.303550
#
#                                                                 \
# Genre Action & Adventure, Animation, Science Fiction & Fantasy
# Year
# 2014                                                 NaN
# 2015                                                 NaN
# 2016                                          -12.685295
# 2017                                                 NaN
# 2018                                                 NaN
#
#                                                                     \
# Genre Action & Adventure, Comedy Action & Adventure, Comedy, Drama
# Year
# 2014                  273.974461                               NaN
# 2015                   -0.500566                        268.742425
# 2016                  106.439158                               NaN
# 2017                   38.633382                        -25.599392
# 2018                  147.697920                               NaN
#
#                                                  ...                \
# Genre Action & Adventure, Comedy, Kids & Family  ... Kids & Family
# Year                                             ...
# 2014                                        NaN  ...           NaN
# 2015                                        NaN  ...           NaN
# 2016                                        NaN  ...     17.281771
# 2017                                        NaN  ...           NaN
# 2018                                  32.286723  ...           NaN
#
#                                                 \
# Genre Kids & Family, Musical & Performing Arts
# Year
# 2014                                128.575664
# 2015                                       NaN
# 2016                                       NaN
# 2017                                       NaN
# 2018                                       NaN
#
#                                                 \
# Genre Kids & Family, Science Fiction & Fantasy
# Year
# 2014                                       NaN
# 2015                                       NaN
# 2016                                -40.528534
# 2017                                       NaN
# 2018                                       NaN
#
#                                                          \
# Genre Kids & Family, Science Fiction & Fantasy, Romance
# Year
# 2014                                                NaN
# 2015                                         111.738266
# 2016                                                NaN
# 2017                                                NaN
# 2018                                                NaN
#
#                                                     \
# Genre Musical & Performing Arts Mystery & Suspense
# Year
# 2014                  17.617532          76.249550
# 2015                        NaN         371.555428
# 2016                        NaN          32.612143
# 2017                        NaN                NaN
# 2018                        NaN         230.478036
#
#                                                                  \
# Genre Mystery & Suspense, Science Fiction & Fantasy     Romance
# Year
# 2014                                      25.422543         NaN
# 2015                                      86.235342  315.418075
# 2016                                            NaN         NaN
# 2017                                            NaN         NaN
# 2018                                     -62.659732         NaN
#
#
# Genre Science Fiction & Fantasy    Western
# Year
# 2014                  34.115182        NaN
# 2015                  35.232999 -12.713845
# 2016                        NaN        NaN
# 2017                        NaN        NaN
# 2018                        NaN        NaN
#
# [5 rows x 86 columns]

# %%
#Create Dataframe from pivot table
MoviesL5yrsbygenre_df = MoviesGerebyYrpivotROI

#view new dataframe 
MoviesL5yrsbygenre_df.head ()
# Out:
#                    ROI %                                        \
# Genre Action & Adventure Action & Adventure, Animation, Comedy
# Year
# 2014           73.148830                                   NaN
# 2015           -3.469511                                   NaN
# 2016           20.111939                             61.151913
# 2017                 NaN                                   NaN
# 2018            3.167880                                   NaN
#
#                                                             \
# Genre Action & Adventure, Animation, Comedy, Kids & Family
# Year
# 2014                                          153.271091
# 2015                                          -33.824129
# 2016                                                 NaN
# 2017                                           57.114832
# 2018                                           35.937105
#
#                                                                                        \
# Genre Action & Adventure, Animation, Comedy, Kids & Family, Science Fiction & Fantasy
# Year
# 2014                                          -15.271158
# 2015                                           36.459623
# 2016                                                 NaN
# 2017                                                 NaN
# 2018                                                 NaN
#
#                                                     \
# Genre Action & Adventure, Animation, Kids & Family
# Year
# 2014                                           NaN
# 2015                                           NaN
# 2016                                     65.838029
# 2017                                           NaN
# 2018                                    201.096616
#
#                                                                                \
# Genre Action & Adventure, Animation, Kids & Family, Science Fiction & Fantasy
# Year
# 2014                                           22.070982
# 2015                                                 NaN
# 2016                                                 NaN
# 2017                                                 NaN
# 2018                                          111.303550
#
#                                                                 \
# Genre Action & Adventure, Animation, Science Fiction & Fantasy
# Year
# 2014                                                 NaN
# 2015                                                 NaN
# 2016                                          -12.685295
# 2017                                                 NaN
# 2018                                                 NaN
#
#                                                                     \
# Genre Action & Adventure, Comedy Action & Adventure, Comedy, Drama
# Year
# 2014                  273.974461                               NaN
# 2015                   -0.500566                        268.742425
# 2016                  106.439158                               NaN
# 2017                   38.633382                        -25.599392
# 2018                  147.697920                               NaN
#
#                                                  ...                \
# Genre Action & Adventure, Comedy, Kids & Family  ... Kids & Family
# Year                                             ...
# 2014                                        NaN  ...           NaN
# 2015                                        NaN  ...           NaN
# 2016                                        NaN  ...     17.281771
# 2017                                        NaN  ...           NaN
# 2018                                  32.286723  ...           NaN
#
#                                                 \
# Genre Kids & Family, Musical & Performing Arts
# Year
# 2014                                128.575664
# 2015                                       NaN
# 2016                                       NaN
# 2017                                       NaN
# 2018                                       NaN
#
#                                                 \
# Genre Kids & Family, Science Fiction & Fantasy
# Year
# 2014                                       NaN
# 2015                                       NaN
# 2016                                -40.528534
# 2017                                       NaN
# 2018                                       NaN
#
#                                                          \
# Genre Kids & Family, Science Fiction & Fantasy, Romance
# Year
# 2014                                                NaN
# 2015                                         111.738266
# 2016                                                NaN
# 2017                                                NaN
# 2018                                                NaN
#
#                                                     \
# Genre Musical & Performing Arts Mystery & Suspense
# Year
# 2014                  17.617532          76.249550
# 2015                        NaN         371.555428
# 2016                        NaN          32.612143
# 2017                        NaN                NaN
# 2018                        NaN         230.478036
#
#                                                                  \
# Genre Mystery & Suspense, Science Fiction & Fantasy     Romance
# Year
# 2014                                      25.422543         NaN
# 2015                                      86.235342  315.418075
# 2016                                            NaN         NaN
# 2017                                            NaN         NaN
# 2018                                     -62.659732         NaN
#
#
# Genre Science Fiction & Fantasy    Western
# Year
# 2014                  34.115182        NaN
# 2015                  35.232999 -12.713845
# 2016                        NaN        NaN
# 2017                        NaN        NaN
# 2018                        NaN        NaN
#
# [5 rows x 86 columns]

# %% [markdown]
# #### proably should made a something for this but just grabbed the genres i needed
# #Horror, Mystery & Suspense
# #Horror
# #Comedy, Musical & Performing Arts
# #Action & Adventure, Horror, Mystery & Suspense
# #Drama, Horror, Mystery & Suspense

# %%
#create df with only top highest avg roi from 2018-2014
top5moviesG = MoviesL5yrsbygenre_df.loc[:,
                                        MoviesL5yrsbygenre_df.columns.get_level_values("Genre").isin(
                                            {"Horror","Comedy, Musical & Performing Arts","Horror, Mystery & Suspense",
                                             "Action & Adventure, Horror, Mystery & Suspense",
                                             "Drama, Horror, Mystery & Suspense"})]

#filled nans with zeroo
top5moviesG.fillna(0, inplace=True)

#view new df
top5moviesG
# Out:
#                                                ROI %  \
# Genre Action & Adventure, Horror, Mystery & Suspense
# Year
# 2014                                        917.1202
# 2015                                          0.0000
# 2016                                        690.4244
# 2017                                        103.3364
# 2018                                          0.0000
#
#                                                                            \
# Genre Comedy, Musical & Performing Arts Drama, Horror, Mystery & Suspense
# Year
# 2014                           0.000000                          0.000000
# 2015                         535.504241                          0.000000
# 2016                           0.000000                          0.000000
# 2017                           0.000000                       1152.609061
# 2018                           0.000000                       1006.025653
#
#
# Genre      Horror Horror, Mystery & Suspense
# Year
# 2014   641.731989                   0.000000
# 2015   238.645791                9015.832200
# 2016   459.282079                 446.956270
# 2017   411.834045                3420.813300
# 2018   519.356774                 147.269567

# %%
#create line graph to visulize the df

top5moviesG.plot(kind = 'line', figsize=(10, 6)).legend(loc='center left', bbox_to_anchor=(1, 0.5))

#rename the labels
plt.legend( loc='best', labels = ['Action & Adventure, Horror, Mystery & Suspense',
                                               'Comedy, Musical & Performing Arts','Drama, Horror, Mystery & Suspense',
                                               'Horror', 'Horror, Mystery & Suspense'])

#style


plt.title("Average ROI from 2014 - 2018")
plt.xlabel("Years")
plt.ylabel("ROI %")
plt.ylim(0)
plt.yticks(np.arange(0, 10000, 500))
plt.xticks(np.arange(2014,2019,1))


#save
plt.savefig('Genre_Aoutput/'+ 'Genreslinegraph.png', bbox_inches='tight')

# %%
#close-up line graph of  top 2 to 4 genres, minus horror, mystery & suppense genre
#create df with only top highest avg roi from 2018-2014
top2to4moviesG = MoviesL5yrsbygenre_df.loc[:,
                                        MoviesL5yrsbygenre_df.columns.get_level_values("Genre").isin(
                                            {"Horror","Comedy, Musical & Performing Arts",
                                             "Action & Adventure, Horror, Mystery & Suspense",
                                             "Drama, Horror, Mystery & Suspense"})]

#filled nans with zeroo
top2to4moviesG.fillna(0, inplace=True)

#create line graph to visulize the df

top2to4moviesG.plot(kind = 'line', figsize=(10, 6)).legend(loc='center left', bbox_to_anchor=(1, 0.5))

#rename the labels
plt.legend( loc='best', labels = ['Action & Adventure, Horror, Mystery & Suspense',
                                               'Comedy, Musical & Performing Arts','Drama, Horror, Mystery & Suspense',
                                               'Horror', 'Horror, Mystery & Suspense'])

#style


plt.title("Average ROI from 2014 - 2018")
plt.xlabel("Years")
plt.ylabel("ROI %")
plt.ylim(0)
plt.yticks(np.arange(0, 1500, 100))
plt.xticks(np.arange(2014,2019,1))


#save
plt.savefig('Genre_Aoutput/'+ 'Genreslinecloseupgraph.png', bbox_inches='tight')

# %% [markdown]
# # Analysis -
#       Tell ya later
