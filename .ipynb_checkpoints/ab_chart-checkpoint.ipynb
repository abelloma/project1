# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.cm as cm


movie_df = pd.read_csv('output/Final_Data.csv')
movie_df.head()
# Out:
#             Title    Budget  Domestic_Gross  Year  Crit_Rating  Aud_Rating  \
# 0   VARSITY BLUES  16000000        52894169  1999           41        76.0
# 1  AT FIRST SIGHT  40000000        22365133  1999           32        46.0
# 2           VIRUS  75000000        14010690  1999           10        21.0
# 3       IN DREAMS  30000000        12017369  1999           24        40.0
# 4   SHES ALL THAT  10000000        63465522  1999           40        55.0
#
#    Runtime_Min                                              Genre MPAA_Rating
# 0        104.0                                              Drama           R
# 1        128.0                                     Drama, Romance       PG-13
# 2        100.0  Action & Adventure, Horror, Science Fiction & ...           R
# 3        120.0                         Horror, Mystery & Suspense           R
# 4         95.0                             Comedy, Drama, Romance       PG-13

# %%
movie_df['ROI'] = (movie_df['Domestic_Gross']/ movie_df['Budget']) *100

movie_df.head()
# Out:
#             Title    Budget  Domestic_Gross  Year  Crit_Rating  Aud_Rating  \
# 0   VARSITY BLUES  16000000        52894169  1999           41        76.0
# 1  AT FIRST SIGHT  40000000        22365133  1999           32        46.0
# 2           VIRUS  75000000        14010690  1999           10        21.0
# 3       IN DREAMS  30000000        12017369  1999           24        40.0
# 4   SHES ALL THAT  10000000        63465522  1999           40        55.0
#
#    Runtime_Min                                              Genre MPAA_Rating  \
# 0        104.0                                              Drama           R
# 1        128.0                                     Drama, Romance       PG-13
# 2        100.0  Action & Adventure, Horror, Science Fiction & ...           R
# 3        120.0                         Horror, Mystery & Suspense           R
# 4         95.0                             Comedy, Drama, Romance       PG-13
#
#           ROI
# 0  330.588556
# 1   55.912833
# 2   18.680920
# 3   40.057897
# 4  634.655220

# %%
bins = [10000000, 15000000, 20000000, 30000000, 40000000, 50000000, 75000000, 100000000, 250000000, 500000000, 1000000000]

group_names = ["<15M", "<20M", "<30M", "<40M", "<50M","<75M","<100M","<250M","<500M","<1B"]

movie_df["Domestic_Cat"] = pd.cut(movie_df["Domestic_Gross"], bins, labels=group_names)
movie_df.head()

movie2 = movie_df.sort_values('Domestic_Cat')
movie2.head()
# movie_groups = movie_df.groupby(movie_df['Year'])
# movie_groups
# movie_groups.head()

# %%
df1999 = movie2[movie2['Year'] == 1999]
df1999

df2000 = movie2[movie2['Year'] == 2000]
df2000

plt.scatter(df1999['Domestic_Gross'], df1999['Crit_Rating'],  color="green", label="1999")
plt.scatter(df2000['Domestic_Gross'], df2000['Crit_Rating'],  color="red", label="2000")


plt.xlabel("Profit")
plt.ylabel("Ratings")

# colors = cm.rainbow(np.linspace(0, 1, 20))
# prev_year = 0

# for (idx, row) in movie_df.iterrows():
#     print(idx)
#     print(movie_df('Year'[idx]))
#     if prev_year == 'Year'[idx]:
#         color= next(colors)
#         prev_year = 'Year'[idx]
# plt.scatter(movie_df['Domestic_Cat'], movie_df['Crit_Rating']) #, color=next(colors))
# # plt.figure(figsize=(10,10))
# plt.xticks(rotation=90, ha="right")

# %%
# Split up our data into groups based upon 'gender'
test2 = pd.pivot_table(movie_df,index=["Year", "MPAA_Rating"], values = "ROI", aggfunc=[np.mean])


# Find out how many of each gender took bike trips
#rating_count = rating_groups['MPAA_Rating'].count()
test2


test2.reset_index(inplace=True)
test2['C'] = test2['Year'].astype(str) + test2['MPAA_Rating']
test2
# Out:
#     Year MPAA_Rating        mean          C
#                              ROI
# 0   1999           G  183.192692      1999G
# 1   1999          PG  159.262103     1999PG
# 2   1999       PG-13  178.358823  1999PG-13
# 3   1999           R  567.709519      1999R
# 4   2000           G  166.682893      2000G
# ..   ...         ...         ...        ...
# 74  2017           R  319.977996      2017R
# 75  2018          NR   98.027910     2018NR
# 76  2018          PG  272.924818     2018PG
# 77  2018       PG-13  242.971440  2018PG-13
# 78  2018           R  252.714324      2018R
#
# [79 rows x 4 columns]

# %%
G = test2[test2['MPAA_Rating'] == 'G']
PG = test2[test2['MPAA_Rating'] == 'PG']
PG_13 = test2[test2['MPAA_Rating'] == 'PG-13']
R = test2[test2['MPAA_Rating'] == 'R']
NR = test2[test2['MPAA_Rating'] == 'NR']

df1999 = test2[test2['Year'] == 2000]
df1999

df2000 = test2[test2['Year'] == 2000]
df2000

# plt.scatter(df1999['Domestic_Gross'], df1999['Crit_Rating'],  color="green", label="1999")

# plt.plot(G['C'], G['mean']['ROI'], color='green')
# plt.plot(PG['C'], PG['mean']['ROI'], color='red')

plt.plot(G['Year'], G['mean']['ROI'], color='green')
#G.plot(figsize=(20,20))
# plt.plot(figsize=(50,30))
plt.plot(PG['Year'], PG['mean']['ROI'], color='pink')
plt.plot(PG_13['Year'], PG_13['mean']['ROI'], color='blue')
plt.plot(R['Year'], R['mean']['ROI'], color='orange')
plt.plot(NR['Year'], NR['mean']['ROI'], color='black')

# %%
rating_groups.head()

rating_groups = test2.T
rating_groups.head()
# Out:
#                       0        1          2       3        4        5   \
# Year                1999     1999       1999    1999     2000     2000
# MPAA_Rating            G       PG      PG-13       R        G       PG
# mean        ROI  183.193  159.262    178.359  567.71  166.683  221.012
# C                  1999G   1999PG  1999PG-13   1999R    2000G   2000PG
#
#                         6        7      8        9   ...         69       70  \
# Year                  2000     2000   2001     2001  ...       2016     2016
# MPAA_Rating          PG-13        R      G       PG  ...      PG-13        R
# mean        ROI    145.267  174.874  325.8  186.345  ...    193.811  261.979
# C                2000PG-13    2000R  2001G   2001PG  ...  2016PG-13    2016R
#
#                       71       72         73       74       75       76  \
# Year                2017     2017       2017     2017     2018     2018
# MPAA_Rating            G       PG      PG-13        R       NR       PG
# mean        ROI  87.3721  202.933    222.425  319.978  98.0279  272.925
# C                  2017G   2017PG  2017PG-13    2017R   2018NR   2018PG
#
#                         77       78
# Year                  2018     2018
# MPAA_Rating          PG-13        R
# mean        ROI    242.971  252.714
# C                2018PG-13    2018R
#
# [4 rows x 79 columns]

# %%
plt.scatter(rating_groups['ROI'], rating_groups['Crit_Rating'],  color="green")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-bb731a96307a> in <module>
# ----> 1 plt.scatter(rating_groups['ROI'], rating_groups['Crit_Rating'],  color="green")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4496                 offsets=offsets,
#    4497                 transOffset=kwargs.pop('transform', self.transData),
# -> 4498                 alpha=alpha
#    4499                 )
#    4500         collection.set_transform(mtransforms.IdentityTransform())
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     881         """
#     882
# --> 883         Collection.__init__(self, **kwargs)
#     884         self.set_paths(paths)
#     885         self.set_sizes(sizes)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     149         self._uniform_offsets = None
#     150         if offsets is not None:
# --> 151             offsets = np.asanyarray(offsets, float)
#     152             # Broadcast (2,) -> (1, 2) but nothing else.
#     153             if offsets.shape == (2,):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py in asanyarray(a, dtype, order)
#     136
#     137     """
# --> 138     return array(a, dtype, copy=False, order=order, subok=True)
#     139
#     140
#
# ValueError: setting an array element with a sequence.
